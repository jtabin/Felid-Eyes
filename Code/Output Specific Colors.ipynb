# %%
# import packages
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image, ImageDraw, ImageColor
import numpy as np
import umap
import os
import math
import itertools

# %%
node_dat = pd.read_csv(".../Node_col_data.csv")
node_dat
# Out:
#     Node  brown_pres brown_pri brown_sec  brown_col_num  brown_light_R  \
# 0      1           1         l         m            3.0      80.509393
# 1      2           1         l         m            3.0     123.896177
# 2      3           1         m         d            3.0     123.869019
# 3      4           1         m         d            3.0     120.890054
# 4      5           1         m         d            3.0     121.933151
# 5      6           1         l         d            3.0     125.220539
# 6      7           1         m         d            3.0     129.150407
# 7      8           1       NaN       NaN            NaN            NaN
# 8      9           0       NaN       NaN            NaN            NaN
# 9     10           0       NaN       NaN            NaN            NaN
# 10    11           0       NaN       NaN            NaN            NaN
# 11    12           0       NaN       NaN            NaN            NaN
# ...

# %%
# get node colors
col = ["brown","hazgre","yelbei","gray","blue"]

for j in range(len(col)):
    os.mkdir(".../Shades/" + str(col[j]))

    for i in range(len(node_dat)):
        # load in background image
        im = Image.open('.../Shades/shade_bg.png')
        draw = ImageDraw.Draw(im)

        # color the image using the data and size info
        if (node_dat.iloc[i][str(col[j])+'_pri'] != node_dat.iloc[i][str(col[j])+'_pri']) != True:
            if node_dat.iloc[i][str(col[j])+'_col_num'] == 3:
                if node_dat.iloc[i][str(col[j])+'_pri'] == node_dat.iloc[i][str(col[j])+'_sec']:
                    if node_dat.iloc[i][str(col[j])+'_pri'] == 'l':
                        draw.rectangle([0, 0, 80, 40],fill=(int(round(node_dat.iloc[i][str(col[j])+'_light_R'])),int(round(node_dat.iloc[i][str(col[j])+'_light_G'])),int(round(node_dat.iloc[i][str(col[j])+'_light_B']))))
                        draw.rectangle([0, 40, 40, 80],fill=(int(round(node_dat.iloc[i][str(col[j])+'_med_R'])),int(round(node_dat.iloc[i][str(col[j])+'_med_G'])),int(round(node_dat.iloc[i][str(col[j])+'_med_B'])))) 
                        draw.rectangle([40, 40, 80, 80],fill=(int(round(node_dat.iloc[i][str(col[j])+'_dark_R'])),int(round(node_dat.iloc[i][str(col[j])+'_dark_G'])),int(round(node_dat.iloc[i][str(col[j])+'_dark_B'])))) 
                    if node_dat.iloc[i][str(col[j])+'_pri'] == 'm':
                        draw.rectangle([0, 0, 80, 40],fill=(int(round(node_dat.iloc[i][str(col[j])+'_med_R'])),int(round(node_dat.iloc[i][str(col[j])+'_med_G'])),int(round(node_dat.iloc[i][str(col[j])+'_med_B']))))    
                        draw.rectangle([0, 40, 40, 80],fill=(int(round(node_dat.iloc[i][str(col[j])+'_light_R'])),int(round(node_dat.iloc[i][str(col[j])+'_light_G'])),int(round(node_dat.iloc[i][str(col[j])+'_light_B']))))
                        draw.rectangle([40, 40, 80, 80],fill=(int(round(node_dat.iloc[i][str(col[j])+'_dark_R'])),int(round(node_dat.iloc[i][str(col[j])+'_dark_G'])),int(round(node_dat.iloc[i][str(col[j])+'_dark_B']))))
                    if node_dat.iloc[i][str(col[j])+'_pri'] == 'd':
                        draw.rectangle([0, 0, 80, 40],fill=(int(round(node_dat.iloc[i][str(col[j])+'_dark_R'])),int(round(node_dat.iloc[i][str(col[j])+'_dark_G'])),int(round(node_dat.iloc[i][str(col[j])+'_dark_B']))))    
                        draw.rectangle([0, 40, 40, 80],fill=(int(round(node_dat.iloc[i][str(col[j])+'_light_R'])),int(round(node_dat.iloc[i][str(col[j])+'_light_G'])),int(round(node_dat.iloc[i][str(col[j])+'_light_B']))))
                        draw.rectangle([40, 40, 80, 80],fill=(int(round(node_dat.iloc[i][str(col[j])+'_med_R'])),int(round(node_dat.iloc[i][str(col[j])+'_med_G'])),int(round(node_dat.iloc[i][str(col[j])+'_med_B']))))
                if node_dat.iloc[i][str(col[j])+'_pri'] == "l" and node_dat.iloc[i][str(col[j])+'_pri'] != node_dat.iloc[i][str(col[j])+'_sec']:
                    draw.rectangle([0, 0, 80, 35],fill=(int(round(node_dat.iloc[i][str(col[j])+'_light_R'])),int(round(node_dat.iloc[i][str(col[j])+'_light_G'])),int(round(node_dat.iloc[i][str(col[j])+'_light_B']))))
                    if node_dat.iloc[i][str(col[j])+'_sec'] == "m":
                        draw.rectangle([0, 35, 80, 60],fill=(int(round(node_dat.iloc[i][str(col[j])+'_med_R'])),int(round(node_dat.iloc[i][str(col[j])+'_med_G'])),int(round(node_dat.iloc[i][str(col[j])+'_med_B']))))
                        draw.rectangle([0, 60, 80, 80],fill=(int(round(node_dat.iloc[i][str(col[j])+'_dark_R'])),int(round(node_dat.iloc[i][str(col[j])+'_dark_G'])),int(round(node_dat.iloc[i][str(col[j])+'_dark_B']))))
                    if node_dat.iloc[i][str(col[j])+'_sec'] == "d":
                        draw.rectangle([0, 35, 80, 60],fill=(int(round(node_dat.iloc[i][str(col[j])+'_dark_R'])),int(round(node_dat.iloc[i][str(col[j])+'_dark_G'])),int(round(node_dat.iloc[i][str(col[j])+'_dark_B']))))
                        draw.rectangle([0, 60, 80, 80],fill=(int(round(node_dat.iloc[i][str(col[j])+'_med_R'])),int(round(node_dat.iloc[i][str(col[j])+'_med_G'])),int(round(node_dat.iloc[i][str(col[j])+'_med_B']))))
                if node_dat.iloc[i][str(col[j])+'_pri'] == "m" and node_dat.iloc[i][str(col[j])+'_pri'] != node_dat.iloc[i][str(col[j])+'_sec']:
                    draw.rectangle([0, 0, 80, 35],fill=(int(round(node_dat.iloc[i][str(col[j])+'_med_R'])),int(round(node_dat.iloc[i][str(col[j])+'_med_G'])),int(round(node_dat.iloc[i][str(col[j])+'_med_B']))))
                    if node_dat.iloc[i][str(col[j])+'_sec'] == "l":
                        draw.rectangle([0, 35, 80, 60],fill=(int(round(node_dat.iloc[i][str(col[j])+'_light_R'])),int(round(node_dat.iloc[i][str(col[j])+'_light_G'])),int(round(node_dat.iloc[i][str(col[j])+'_light_B']))))
                        draw.rectangle([0, 60, 80, 80],fill=(int(round(node_dat.iloc[i][str(col[j])+'_dark_R'])),int(round(node_dat.iloc[i][str(col[j])+'_dark_G'])),int(round(node_dat.iloc[i][str(col[j])+'_dark_B']))))
                    if node_dat.iloc[i][str(col[j])+'_sec'] == "d":
                        draw.rectangle([0, 35, 80, 60],fill=(int(round(node_dat.iloc[i][str(col[j])+'_dark_R'])),int(round(node_dat.iloc[i][str(col[j])+'_dark_G'])),int(round(node_dat.iloc[i][str(col[j])+'_dark_B']))))
                        draw.rectangle([0, 60, 80, 80],fill=(int(round(node_dat.iloc[i][str(col[j])+'_light_R'])),int(round(node_dat.iloc[i][str(col[j])+'_light_G'])),int(round(node_dat.iloc[i][str(col[j])+'_light_B']))))
                if node_dat.iloc[i][str(col[j])+'_pri'] == "d" and node_dat.iloc[i][str(col[j])+'_pri'] != node_dat.iloc[i][str(col[j])+'_sec']:
                    draw.rectangle([0, 0, 80, 35],fill=(int(round(node_dat.iloc[i][str(col[j])+'_dark_R'])),int(round(node_dat.iloc[i][str(col[j])+'_dark_G'])),int(round(node_dat.iloc[i][str(col[j])+'_dark_B']))))
                    if node_dat.iloc[i][str(col[j])+'_sec'] == "l":
                        draw.rectangle([0, 35, 80, 60],fill=(int(round(node_dat.iloc[i][str(col[j])+'_light_R'])),int(round(node_dat.iloc[i][str(col[j])+'_light_G'])),int(round(node_dat.iloc[i][str(col[j])+'_light_B']))))
                        draw.rectangle([0, 60, 80, 80],fill=(int(round(node_dat.iloc[i][str(col[j])+'_med_R'])),int(round(node_dat.iloc[i][str(col[j])+'_med_G'])),int(round(node_dat.iloc[i][str(col[j])+'_med_B']))))
                    if node_dat.iloc[i][str(col[j])+'_sec'] == "m":
                        draw.rectangle([0, 35, 80, 60],fill=(int(round(node_dat.iloc[i][str(col[j])+'_med_R'])),int(round(node_dat.iloc[i][str(col[j])+'_med_G'])),int(round(node_dat.iloc[i][str(col[j])+'_med_B']))))
                        draw.rectangle([0, 60, 80, 80],fill=(int(round(node_dat.iloc[i][str(col[j])+'_light_R'])),int(round(node_dat.iloc[i][str(col[j])+'_light_G'])),int(round(node_dat.iloc[i][str(col[j])+'_light_B']))))

            if node_dat.iloc[i][str(col[j])+'_col_num'] == 2:

                if (node_dat.iloc[i][str(col[j])+'_light_R'] != node_dat.iloc[i][str(col[j])+'_light_R']) == True:
                    if node_dat.iloc[i][str(col[j])+'_pri'] == 'm':
                        draw.rectangle([0, 0, 80, 60],fill=(int(round(node_dat.iloc[i][str(col[j])+'_med_R'])),int(round(node_dat.iloc[i][str(col[j])+'_med_G'])),int(round(node_dat.iloc[i][str(col[j])+'_med_B']))))
                        draw.rectangle([0, 60, 80, 80],fill=(int(round(node_dat.iloc[i][str(col[j])+'_dark_R'])),int(round(node_dat.iloc[i][str(col[j])+'_dark_G'])),int(round(node_dat.iloc[i][str(col[j])+'_dark_B']))))
                    if node_dat.iloc[i][str(col[j])+'_pri'] == 'd':
                        draw.rectangle([0, 0, 80, 60],fill=(int(round(node_dat.iloc[i][str(col[j])+'_dark_R'])),int(round(node_dat.iloc[i][str(col[j])+'_dark_G'])),int(round(node_dat.iloc[i][str(col[j])+'_dark_B']))))
                        draw.rectangle([0, 60, 80, 80],fill=(int(round(node_dat.iloc[i][str(col[j])+'_med_R'])),int(round(node_dat.iloc[i][str(col[j])+'_med_G'])),int(round(node_dat.iloc[i][str(col[j])+'_med_B']))))
                if (node_dat.iloc[i][str(col[j])+'_med_R'] != node_dat.iloc[i][str(col[j])+'_med_R']) == True:
                    if node_dat.iloc[i][str(col[j])+'_pri'] == 'l':
                        draw.rectangle([0, 0, 80, 60],fill=(int(round(node_dat.iloc[i][str(col[j])+'_light_R'])),int(round(node_dat.iloc[i][str(col[j])+'_light_G'])),int(round(node_dat.iloc[i][str(col[j])+'_light_B']))))
                        draw.rectangle([0, 60, 80, 80],fill=(int(round(node_dat.iloc[i][str(col[j])+'_dark_R'])),int(round(node_dat.iloc[i][str(col[j])+'_dark_G'])),int(round(node_dat.iloc[i][str(col[j])+'_dark_B']))))
                    if node_dat.iloc[i][str(col[j])+'_pri'] == 'd':
                        draw.rectangle([0, 0, 80, 60],fill=(int(round(node_dat.iloc[i][str(col[j])+'_dark_R'])),int(round(node_dat.iloc[i][str(col[j])+'_dark_G'])),int(round(node_dat.iloc[i][str(col[j])+'_dark_B']))))
                        draw.rectangle([0, 60, 80, 80],fill=(int(round(node_dat.iloc[i][str(col[j])+'_light_R'])),int(round(node_dat.iloc[i][str(col[j])+'_light_G'])),int(round(node_dat.iloc[i][str(col[j])+'_light_B']))))
                if (node_dat.iloc[i][str(col[j])+'_dark_R'] != node_dat.iloc[i][str(col[j])+'_dark_R']) == True:
                    if node_dat.iloc[i][str(col[j])+'_pri'] == 'l':
                        draw.rectangle([0, 0, 80, 60],fill=(int(round(node_dat.iloc[i][str(col[j])+'_light_R'])),int(round(node_dat.iloc[i][str(col[j])+'_light_G'])),int(round(node_dat.iloc[i][str(col[j])+'_light_B']))))
                        draw.rectangle([0, 60, 80, 80],fill=(int(round(node_dat.iloc[i][str(col[j])+'_med_R'])),int(round(node_dat.iloc[i][str(col[j])+'_med_G'])),int(round(node_dat.iloc[i][str(col[j])+'_med_B']))))
                    if node_dat.iloc[i][str(col[j])+'_pri'] == 'm':
                        draw.rectangle([0, 0, 80, 60],fill=(int(round(node_dat.iloc[i][str(col[j])+'_med_R'])),int(round(node_dat.iloc[i][str(col[j])+'_med_G'])),int(round(node_dat.iloc[i][str(col[j])+'_med_B']))))
                        draw.rectangle([0, 60, 80, 80],fill=(int(round(node_dat.iloc[i][str(col[j])+'_light_R'])),int(round(node_dat.iloc[i][str(col[j])+'_light_G'])),int(round(node_dat.iloc[i][str(col[j])+'_light_B']))))

            if node_dat.iloc[i][str(col[j])+'_col_num'] == 1:                     
                if node_dat.iloc[i][str(col[j])+'_pri'] == "l":
                    draw.rectangle([0, 0, 80, 80],fill=(int(round(node_dat.iloc[i][str(col[j])+'_light_R'])),int(round(node_dat.iloc[i][str(col[j])+'_light_G'])),int(round(node_dat.iloc[i][str(col[j])+'_light_B']))))
                if node_dat.iloc[i][str(col[j])+'_pri'] == "m":
                    draw.rectangle([0, 0, 80, 80],fill=(int(round(node_dat.iloc[i][str(col[j])+'_med_R'])),int(round(node_dat.iloc[i][str(col[j])+'_med_G'])),int(round(node_dat.iloc[i][str(col[j])+'_med_B']))))
                if node_dat.iloc[i][str(col[j])+'_pri'] == "d":
                    draw.rectangle([0, 0, 80, 80],fill=(int(round(node_dat.iloc[i][str(col[j])+'_dark_R'])),int(round(node_dat.iloc[i][str(col[j])+'_dark_G'])),int(round(node_dat.iloc[i][str(col[j])+'_dark_B']))))

            im.save(".../Shades/" + str(col[j]) + "/Node" + str(i+1)+ ".png","PNG")

# %%
# get tip colors
col = ["brown","hazgre","yelbei","gray","blue"]
node_dat = pd.read_csv(".../Tip_col_data.csv")

for j in range(len(col)):
    for i in range(len(node_dat)):
        # load in background image
        im = Image.open('.../Shades/shade_bg.png')
        draw = ImageDraw.Draw(im)

        # color the image using the data and size info
        if (node_dat.iloc[i][str(col[j])+'_pri'] != node_dat.iloc[i][str(col[j])+'_pri']) != True:
            if node_dat.iloc[i][str(col[j])+'_col_num'] == 3:
                if node_dat.iloc[i][str(col[j])+'_pri'] == "l" and node_dat.iloc[i][str(col[j])+'_pri'] != node_dat.iloc[i][str(col[j])+'_sec']:
                    draw.rectangle([0, 0, 80, 35],fill=(int(round(node_dat.iloc[i][str(col[j])+'_light_R'])),int(round(node_dat.iloc[i][str(col[j])+'_light_G'])),int(round(node_dat.iloc[i][str(col[j])+'_light_B']))))
                    if node_dat.iloc[i][str(col[j])+'_sec'] == "m":
                        draw.rectangle([0, 35, 80, 60],fill=(int(round(node_dat.iloc[i][str(col[j])+'_med_R'])),int(round(node_dat.iloc[i][str(col[j])+'_med_G'])),int(round(node_dat.iloc[i][str(col[j])+'_med_B']))))
                        draw.rectangle([0, 60, 80, 80],fill=(int(round(node_dat.iloc[i][str(col[j])+'_dark_R'])),int(round(node_dat.iloc[i][str(col[j])+'_dark_G'])),int(round(node_dat.iloc[i][str(col[j])+'_dark_B']))))
                    if node_dat.iloc[i][str(col[j])+'_sec'] == "d":
                        draw.rectangle([0, 35, 80, 60],fill=(int(round(node_dat.iloc[i][str(col[j])+'_dark_R'])),int(round(node_dat.iloc[i][str(col[j])+'_dark_G'])),int(round(node_dat.iloc[i][str(col[j])+'_dark_B']))))
                        draw.rectangle([0, 60, 80, 80],fill=(int(round(node_dat.iloc[i][str(col[j])+'_med_R'])),int(round(node_dat.iloc[i][str(col[j])+'_med_G'])),int(round(node_dat.iloc[i][str(col[j])+'_med_B']))))
                if node_dat.iloc[i][str(col[j])+'_pri'] == "m" and node_dat.iloc[i][str(col[j])+'_pri'] != node_dat.iloc[i][str(col[j])+'_sec']:
                    draw.rectangle([0, 0, 80, 35],fill=(int(round(node_dat.iloc[i][str(col[j])+'_med_R'])),int(round(node_dat.iloc[i][str(col[j])+'_med_G'])),int(round(node_dat.iloc[i][str(col[j])+'_med_B']))))
                    if node_dat.iloc[i][str(col[j])+'_sec'] == "l":
                        draw.rectangle([0, 35, 80, 60],fill=(int(round(node_dat.iloc[i][str(col[j])+'_light_R'])),int(round(node_dat.iloc[i][str(col[j])+'_light_G'])),int(round(node_dat.iloc[i][str(col[j])+'_light_B']))))
                        draw.rectangle([0, 60, 80, 80],fill=(int(round(node_dat.iloc[i][str(col[j])+'_dark_R'])),int(round(node_dat.iloc[i][str(col[j])+'_dark_G'])),int(round(node_dat.iloc[i][str(col[j])+'_dark_B']))))
                    if node_dat.iloc[i][str(col[j])+'_sec'] == "d":
                        draw.rectangle([0, 35, 80, 60],fill=(int(round(node_dat.iloc[i][str(col[j])+'_dark_R'])),int(round(node_dat.iloc[i][str(col[j])+'_dark_G'])),int(round(node_dat.iloc[i][str(col[j])+'_dark_B']))))
                        draw.rectangle([0, 60, 80, 80],fill=(int(round(node_dat.iloc[i][str(col[j])+'_light_R'])),int(round(node_dat.iloc[i][str(col[j])+'_light_G'])),int(round(node_dat.iloc[i][str(col[j])+'_light_B']))))
                if node_dat.iloc[i][str(col[j])+'_pri'] == "d" and node_dat.iloc[i][str(col[j])+'_pri'] != node_dat.iloc[i][str(col[j])+'_sec']:
                    draw.rectangle([0, 0, 80, 35],fill=(int(round(node_dat.iloc[i][str(col[j])+'_dark_R'])),int(round(node_dat.iloc[i][str(col[j])+'_dark_G'])),int(round(node_dat.iloc[i][str(col[j])+'_dark_B']))))
                    if node_dat.iloc[i][str(col[j])+'_sec'] == "l":
                        draw.rectangle([0, 35, 80, 60],fill=(int(round(node_dat.iloc[i][str(col[j])+'_light_R'])),int(round(node_dat.iloc[i][str(col[j])+'_light_G'])),int(round(node_dat.iloc[i][str(col[j])+'_light_B']))))
                        draw.rectangle([0, 60, 80, 80],fill=(int(round(node_dat.iloc[i][str(col[j])+'_med_R'])),int(round(node_dat.iloc[i][str(col[j])+'_med_G'])),int(round(node_dat.iloc[i][str(col[j])+'_med_B']))))
                    if node_dat.iloc[i][str(col[j])+'_sec'] == "m":
                        draw.rectangle([0, 35, 80, 60],fill=(int(round(node_dat.iloc[i][str(col[j])+'_med_R'])),int(round(node_dat.iloc[i][str(col[j])+'_med_G'])),int(round(node_dat.iloc[i][str(col[j])+'_med_B']))))
                        draw.rectangle([0, 60, 80, 80],fill=(int(round(node_dat.iloc[i][str(col[j])+'_light_R'])),int(round(node_dat.iloc[i][str(col[j])+'_light_G'])),int(round(node_dat.iloc[i][str(col[j])+'_light_B']))))

            if node_dat.iloc[i][str(col[j])+'_col_num'] == 2:
                if node_dat.iloc[i][str(col[j])+'_pri'] == "l" and node_dat.iloc[i][str(col[j])+'_pri'] != node_dat.iloc[i][str(col[j])+'_sec']:
                    draw.rectangle([0, 0, 80, 60],fill=(int(round(node_dat.iloc[i][str(col[j])+'_light_R'])),int(round(node_dat.iloc[i][str(col[j])+'_light_G'])),int(round(node_dat.iloc[i][str(col[j])+'_light_B']))))
                    if node_dat.iloc[i][str(col[j])+'_sec'] == "m":
                        draw.rectangle([0, 60, 80, 80],fill=(int(round(node_dat.iloc[i][str(col[j])+'_med_R'])),int(round(node_dat.iloc[i][str(col[j])+'_med_G'])),int(round(node_dat.iloc[i][str(col[j])+'_med_B']))))
                    if node_dat.iloc[i][str(col[j])+'_sec'] == "d":
                        draw.rectangle([0, 60, 80, 80],fill=(int(round(node_dat.iloc[i][str(col[j])+'_dark_R'])),int(round(node_dat.iloc[i][str(col[j])+'_dark_G'])),int(round(node_dat.iloc[i][str(col[j])+'_dark_B']))))
                if node_dat.iloc[i][str(col[j])+'_pri'] == "m" and node_dat.iloc[i][str(col[j])+'_pri'] != node_dat.iloc[i][str(col[j])+'_sec']:
                    draw.rectangle([0, 0, 80, 60],fill=(int(round(node_dat.iloc[i][str(col[j])+'_med_R'])),int(round(node_dat.iloc[i][str(col[j])+'_med_G'])),int(round(node_dat.iloc[i][str(col[j])+'_med_B']))))
                    if node_dat.iloc[i][str(col[j])+'_sec'] == "l":
                        draw.rectangle([0, 60, 80, 80],fill=(int(round(node_dat.iloc[i][str(col[j])+'_light_R'])),int(round(node_dat.iloc[i][str(col[j])+'_light_G'])),int(round(node_dat.iloc[i][str(col[j])+'_light_B']))))
                    if node_dat.iloc[i][str(col[j])+'_sec'] == "d":
                        draw.rectangle([0, 60, 80, 80],fill=(int(round(node_dat.iloc[i][str(col[j])+'_dark_R'])),int(round(node_dat.iloc[i][str(col[j])+'_dark_G'])),int(round(node_dat.iloc[i][str(col[j])+'_dark_B']))))
                if node_dat.iloc[i][str(col[j])+'_pri'] == "d" and node_dat.iloc[i][str(col[j])+'_pri'] != node_dat.iloc[i][str(col[j])+'_sec']:
                    draw.rectangle([0, 0, 80, 60],fill=(int(round(node_dat.iloc[i][str(col[j])+'_dark_R'])),int(round(node_dat.iloc[i][str(col[j])+'_dark_G'])),int(round(node_dat.iloc[i][str(col[j])+'_dark_B']))))
                    if node_dat.iloc[i][str(col[j])+'_sec'] == "l":
                        draw.rectangle([0, 60, 80, 80],fill=(int(round(node_dat.iloc[i][str(col[j])+'_light_R'])),int(round(node_dat.iloc[i][str(col[j])+'_light_G'])),int(round(node_dat.iloc[i][str(col[j])+'_light_B']))))
                    if node_dat.iloc[i][str(col[j])+'_sec'] == "m":
                        draw.rectangle([0, 60, 80, 80],fill=(int(round(node_dat.iloc[i][str(col[j])+'_med_R'])),int(round(node_dat.iloc[i][str(col[j])+'_med_G'])),int(round(node_dat.iloc[i][str(col[j])+'_med_B']))))

            if node_dat.iloc[i][str(col[j])+'_col_num'] == 1:                     
                if node_dat.iloc[i][str(col[j])+'_pri'] == "l":
                    draw.rectangle([0, 0, 80, 80],fill=(int(round(node_dat.iloc[i][str(col[j])+'_light_R'])),int(round(node_dat.iloc[i][str(col[j])+'_light_G'])),int(round(node_dat.iloc[i][str(col[j])+'_light_B']))))
                if node_dat.iloc[i][str(col[j])+'_pri'] == "m":
                    draw.rectangle([0, 0, 80, 80],fill=(int(round(node_dat.iloc[i][str(col[j])+'_med_R'])),int(round(node_dat.iloc[i][str(col[j])+'_med_G'])),int(round(node_dat.iloc[i][str(col[j])+'_med_B']))))
                if node_dat.iloc[i][str(col[j])+'_pri'] == "d":
                    draw.rectangle([0, 0, 80, 80],fill=(int(round(node_dat.iloc[i][str(col[j])+'_dark_R'])),int(round(node_dat.iloc[i][str(col[j])+'_dark_G'])),int(round(node_dat.iloc[i][str(col[j])+'_dark_B']))))
                    
            if node_dat.iloc[i][str(col[j])+'_col_num'] == 4:
                if node_dat.iloc[i][str(col[j])+'_order'] == "deml":
                    draw.rectangle([0, 0, 80, 30],fill=(int(round(node_dat.iloc[i][str(col[j])+'_dark_R'])),int(round(node_dat.iloc[i][str(col[j])+'_dark_G'])),int(round(node_dat.iloc[i][str(col[j])+'_dark_B']))))
                    draw.rectangle([0, 30, 80, 55],fill=(int(round(node_dat.iloc[i][str(col[j])+'_excl_R'])),int(round(node_dat.iloc[i][str(col[j])+'_excl_G'])),int(round(node_dat.iloc[i][str(col[j])+'_excl_B']))))
                    draw.rectangle([0, 55, 80, 70],fill=(int(round(node_dat.iloc[i][str(col[j])+'_med_R'])),int(round(node_dat.iloc[i][str(col[j])+'_med_G'])),int(round(node_dat.iloc[i][str(col[j])+'_med_B']))))
                    draw.rectangle([0, 70, 80, 80],fill=(int(round(node_dat.iloc[i][str(col[j])+'_light_R'])),int(round(node_dat.iloc[i][str(col[j])+'_light_G'])),int(round(node_dat.iloc[i][str(col[j])+'_light_B']))))
                if node_dat.iloc[i][str(col[j])+'_order'] == "emld":
                    draw.rectangle([0, 0, 80, 30],fill=(int(round(node_dat.iloc[i][str(col[j])+'_excl_R'])),int(round(node_dat.iloc[i][str(col[j])+'_excl_G'])),int(round(node_dat.iloc[i][str(col[j])+'_excl_B']))))
                    draw.rectangle([0, 30, 80, 55],fill=(int(round(node_dat.iloc[i][str(col[j])+'_med_R'])),int(round(node_dat.iloc[i][str(col[j])+'_med_G'])),int(round(node_dat.iloc[i][str(col[j])+'_med_B']))))
                    draw.rectangle([0, 55, 80, 70],fill=(int(round(node_dat.iloc[i][str(col[j])+'_light_R'])),int(round(node_dat.iloc[i][str(col[j])+'_light_G'])),int(round(node_dat.iloc[i][str(col[j])+'_light_B']))))
                    draw.rectangle([0, 70, 80, 80],fill=(int(round(node_dat.iloc[i][str(col[j])+'_dark_R'])),int(round(node_dat.iloc[i][str(col[j])+'_dark_G'])),int(round(node_dat.iloc[i][str(col[j])+'_dark_B']))))
                if node_dat.iloc[i][str(col[j])+'_order'] == "slsd":
                    draw.rectangle([0, 0, 80, 30],fill=(int(round(node_dat.iloc[i][str(col[j])+'_excl_R'])),int(round(node_dat.iloc[i][str(col[j])+'_excl_G'])),int(round(node_dat.iloc[i][str(col[j])+'_excl_B']))))
                    draw.rectangle([0, 55, 80, 70],fill=(int(round(node_dat.iloc[i][str(col[j])+'_med_R'])),int(round(node_dat.iloc[i][str(col[j])+'_med_G'])),int(round(node_dat.iloc[i][str(col[j])+'_med_B']))))
                    draw.rectangle([0, 30, 80, 55],fill=(int(round(node_dat.iloc[i][str(col[j])+'_light_R'])),int(round(node_dat.iloc[i][str(col[j])+'_light_G'])),int(round(node_dat.iloc[i][str(col[j])+'_light_B']))))
                    draw.rectangle([0, 70, 80, 80],fill=(int(round(node_dat.iloc[i][str(col[j])+'_dark_R'])),int(round(node_dat.iloc[i][str(col[j])+'_dark_G'])),int(round(node_dat.iloc[i][str(col[j])+'_dark_B']))))
                    
            im.save(".../Shades/" + str(col[j]) + "/" + str(node_dat.iloc[i]['Rename']) + ".png","PNG")
